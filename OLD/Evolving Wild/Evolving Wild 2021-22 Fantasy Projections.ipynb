# %%
import pandas as pd
import plotly

# %%
df = pd.read_csv(r'C:\Users\jwini\OneDrive\Documents\Python Scripts\hockey-analytics\Evolving Wild\EH_fantasy_projections_pts_league_All_pos_2021-09-08.csv')

# %% [markdown]
# forwards = df['Pos'] == 'F'
# forwards = df[forwards]
# defenseman = df['Pos'] == 'D'
# defenseman = df[defenseman]
# goalies = df['Pos'] == 'G'
# goalies = df[goalies]

# %% [markdown]
# # Forwards

# %%
#Best Goal Scorers
forwards.sort_values(['G'], ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %%
# Best Assists
forwards.sort_values(by = 'A', ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %%
# Best Points
forwards.sort_values(by = 'Pts', ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %%
# Best Shots on Goal
forwards.sort_values(by = 'SOG', ascending =[False])
print(forwards.head(20))

# %%
# Best Blocks
forwards.sort_values(by = 'BLK', ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %%
# Best Hits
forwards.sort_values(by = 'HIT', ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %%
# Best Shorthanded Points
forwards.sort_values(by = 'SHP', ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %%
# Best Powerplay Points
forwards.sort_values(by = 'PPP', ascending =[False])
print(forwards.head(20))
# Out:
#                 Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 0       Connor McDavid   F  21-22  EDM  82  1790  21.8  46  70  116  ...   32
# 1     Nathan MacKinnon   F  21-22  COL  82  1713  20.9  41  72  112  ...   27
# 2       Leon Draisaitl   F  21-22  EDM  82  1781  21.7  44  69  113  ...   26
# 3      Nikita Kucherov   F  21-22  T.B  82  1565  19.1  44  71  115  ...   24
# 4      Auston Matthews   F  21-22  TOR  82  1754  21.4  46  45   91  ...   73
# 6        Brad Marchand   F  21-22  BOS  82  1509  18.4  39  64  103  ...   24
# 7   Jonathan Huberdeau   F  21-22  FLA  82  1502  18.3  37  69  106  ...   20
# 9        Sebastian Aho   F  21-22  CAR  82  1634  19.9  43  52   95  ...   46
# 10      Mark Scheifele   F  21-22  WPG  82  1685  20.5  38  66  104  ...   54
# 11      Mikko Rantanen   F  21-22  COL  78  1538  19.8  39  55   94  ...   27
# 12   Aleksander Barkov   F  21-22  FLA  82  1705  20.8  36  57   93  ...   61
# ...

# %% [markdown]
# # Defenseman

# %%
## Best Goal Scorers
defenseman.sort_values(by='G', ascending =[False])
print(defenseman.head(20))

## Best Assists
defenseman.sort_values(by = 'A', ascending =[False])
print(defenseman.head(20))

#Best Points
defenseman.sort_values(by = 'Pts', ascending =[False])
print(defenseman.head(20))

#Best Shots on Goal
defenseman.sort_values(by = 'SOG', ascending =[False])
print(defenseman.head(20))

#Best Blocks
defenseman.sort_values(by = 'BLK', ascending =[False])
print(defenseman.head(20))

#Best Hits
defenseman.sort_values(by = 'HIT', ascending =[False])
print(defenseman.head(20))


#Best Shorthanded Points
defenseman.sort_values(by = 'SHP', ascending =[False])
print(defenseman.head(20))


#Best Powerplay Points
defenseman.sort_values(by = 'PPP', ascending =[False])
print(defenseman.head(20))
# Out:
#               Player Pos Season Team  GP   TOI  ATOI   G   A  Pts  ...  BLK  \
# 25    Jakob Chychrun   D  21-22  ARI  82  1908  23.3  23  39   62  ...  141
# 27      John Carlson   D  21-22  WSH  82  1923  23.4  14  61   75  ...  123
# 31          Adam Fox   D  21-22  NYR  82  1892  23.1  11  58   69  ...  156
# 33     Victor Hedman   D  21-22  T.B  82  1963  23.9  14  54   68  ...  110
# 34        Cale Makar   D  21-22  COL  82  2001  24.4  15  55   71  ...   78
# 35   Dougie Hamilton   D  21-22  N.J  82  1834  22.4  16  49   65  ...   91
# 45        Roman Josi   D  21-22  NSH  82  1986  24.2  15  48   62  ...  133
# 55     Shea Theodore   D  21-22  VGK  82  1847  22.5  13  49   62  ...   80
# 58     Darnell Nurse   D  21-22  EDM  82  2022  24.7  17  32   49  ...  169
# 60        Jeff Petry   D  21-22  MTL  82  1872  22.8  15  42   57  ...  105
# 61      Tyson Barrie   D  21-22  EDM  82  1736  21.2  10  50   60  ...   89
# ...

# %% [markdown]
# # Goalies

# %%
# Wins
goalies.sort_values(by = 'W', ascending =[False])
print(goalies.head(20))

# Saves
goalies.sort_values(by = 'SV', ascending =[False])
print(goalies.head(20))

# Goals Against
goalies.sort_values(by = 'GA', ascending =[False])
print(goalies.head(20))
# Out:
#                   Player Pos Season Team  GP  TOI  ATOI  G  A  Pts  ...  BLK  \
# 5      Connor Hellebuyck   G  21-22  WPG   0    0   0.0  0  0    0  ...    0
# 8            Juuse Saros   G  21-22  NSH   0    0   0.0  0  0    0  ...    0
# 13    Andrei Vasilevskiy   G  21-22  T.B   0    0   0.0  0  0    0  ...    0
# 20       Semyon Varlamov   G  21-22  NYI   0    0   0.0  0  0    0  ...    0
# 37       Jacob Markstrom   G  21-22  CGY   0    0   0.0  0  0    0  ...    0
# 43           Carey Price   G  21-22  MTL   0    0   0.0  0  0    0  ...    0
# 53      Philipp Grubauer   G  21-22  SEA   0    0   0.0  0  0    0  ...    0
# 54           Tuukka Rask   G  21-22    -   0    0   0.0  0  0    0  ...    0
# 69     Marc-Andre Fleury   G  21-22  CHI   0    0   0.0  0  0    0  ...    0
# 70        Thatcher Demko   G  21-22  VAN   0    0   0.0  0  0    0  ...    0
# 74     Jordan Binnington   G  21-22  STL   0    0   0.0  0  0    0  ...    0
# ...
