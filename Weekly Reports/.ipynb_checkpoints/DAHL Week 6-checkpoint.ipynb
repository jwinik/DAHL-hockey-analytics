# %% [markdown]
# # DAHL Week 6

# %% [markdown]
# ## Setup

# %%
import path
import os
from espn_api.hockey import League

# %%
setup_path = "C:/Users/jwini/OneDrive/Documents/Python Scripts/hockey-analytics/Setup Files/"
cred_fname = "credentials.py"
matchup_fname = "DAHL Matchup Stats.py"
player_fname = "DAHL Player Stats.py"

setup_files = [cred_fname, matchup_fname]

# %%
for f in setup_files:
    exec(open(os.path.join(setup_path, f)).read())

# %%
league = League(league_id = 1140371907, year = 2022, espn_s2 = espn_s2, swid = swid)

# %%
matchup_week1 = get_matchup_stats_to_df(1)
matchup_week2 = get_matchup_stats_to_df(2)
matchup_week3 = get_matchup_stats_to_df(3)
matchup_week4 = get_matchup_stats_to_df(4)
matchup_week5 = get_matchup_stats_to_df(5)
matchup_week6 = get_matchup_stats_to_df(6)

# %%
week1 = clean_matchup_df(matchup_week1)
week2 = clean_matchup_df(matchup_week2)
week3 = clean_matchup_df(matchup_week3)        
week4 = clean_matchup_df(matchup_week4)        
week5 = clean_matchup_df(matchup_week5)
week6 = clean_matchup_df(matchup_week6)
matchup_weeks = [week1, week2, week3, week4, week5, week6]

# %%
matchup_df_clean = clean_matchup_dfs(matchup_weeks)

# %% [markdown]
# ## Matchup Plots Week 6

# %%
plot_weekly_points(matchup_df_clean,7)

# %%
plot_week_bar(matchup_df_clean,6)

# %%
matchup_tables(matchup_df_clean, "Fantasy Points")
# Out:
# Week Number  index                     Team Name       1       2       3  \
# 0                0             Baltimore Bandits  158.80  202.95  223.55
# 1                1  Brown Shoes w/ a Black Belt?  129.40  165.50  181.10
# 2                2                 Carolina Tony  125.00  157.60  199.75
# 3                3         Esther Island Esthers  160.00  204.65  207.40
# 4                4         Lausanne  Automatons   121.05  211.30  230.00
# 5                5                 THE FirePucks   88.60  191.50  147.50
# 6                6                 Team Ginsberg  137.40  166.05  173.35
# 7                7                   Team Hector  141.55  171.05   77.70
# 8                8         That Hoser Over There  129.45  176.85  198.25
# 9                9            Vasili's POD SQUAD  133.55  212.40  168.45
#
# Week Number       4       5       6     Average    Total
# 0            192.15  239.65  170.30  169.628571  1187.40
# 1            187.20  158.95  134.75  136.842857   957.90
# 2            255.85  258.10  179.45  168.250000  1177.75
# 3            214.50  183.10  130.90  157.650000  1103.55
# 4            152.85  163.10  128.70  144.428571  1011.00
# 5            169.35  162.35  109.60  124.842857   873.90
# 6            251.10  203.10  195.45  161.778571  1132.45
# 7            158.45  111.70  116.25  111.957143   783.70
# 8            206.65  189.30  165.35  153.407143  1073.85
# 9            202.35  199.80  182.90  158.350000  1108.45

# %%
matchup_tables(matchup_df_clean, "Opponent Fantasy Points")
# Out:
# Week Number  index                     Team Name       1       2       3  \
# 0                0             Baltimore Bandits  129.40  176.85  230.00
# 1                1  Brown Shoes w/ a Black Belt?  158.80  211.30  147.50
# 2                2                 Carolina Tony  141.55  166.05  168.45
# 3                3         Esther Island Esthers  129.45  171.05  173.35
# 4                4         Lausanne  Automatons   133.55  165.50  223.55
# 5                5                 THE FirePucks  137.40  212.40  181.10
# 6                6                 Team Ginsberg   88.60  157.60  207.40
# 7                7                   Team Hector  125.00  204.65  198.25
# 8                8         That Hoser Over There  160.00  202.95   77.70
# 9                9            Vasili's POD SQUAD  121.05  191.50  199.75
#
# Week Number       4       5       6     Average    Total
# 0            169.35  199.80  195.45  157.264286  1100.85
# 1            202.35  183.10  116.25  145.757143  1020.30
# 2            214.50  189.30  128.70  144.364286  1010.55
# 3            255.85  158.95  109.60  143.035714  1001.25
# 4            158.45  162.35  179.45  146.692857  1026.85
# 5            192.15  163.10  130.90  146.007143  1022.05
# 6            206.65  111.70  170.30  135.464286   948.25
# 7            152.85  203.10  134.75  146.514286  1025.60
# 8            251.10  258.10  182.90  162.964286  1140.75
# 9            187.20  239.65  165.35  159.071429  1113.50

# %%
matchup_tables(matchup_df_clean, "Fantasy Points Rank")
# Out:
# Week Number                     Team Name     1     2     3     4     5     6  \
# 0                       Baltimore Bandits   2.0   4.0   2.0   6.0   2.0   4.0
# 1            Brown Shoes w/ a Black Belt?   7.0   9.0   6.0   7.0   9.0   6.0
# 2                           Carolina Tony   8.0  10.0   4.0   1.0   1.0   3.0
# 3                   Esther Island Esthers   1.0   3.0   3.0   3.0   6.0   7.0
# 4                   Lausanne  Automatons    9.0   2.0   1.0  10.0   7.0   8.0
# 5                           THE FirePucks  10.0   5.0   9.0   8.0   8.0  10.0
# 6                           Team Ginsberg   4.0   8.0   7.0   2.0   3.0   1.0
# 7                             Team Hector   3.0   7.0  10.0   9.0  10.0   9.0
# 8                   That Hoser Over There   6.0   6.0   5.0   4.0   5.0   5.0
# 9                      Vasili's POD SQUAD   5.0   1.0   8.0   5.0   4.0   2.0
#
# Week Number   Average  Total
# 0            3.333333   20.0
# 1            7.333333   44.0
# 2            4.500000   27.0
# 3            3.833333   23.0
# 4            6.166667   37.0
# 5            8.333333   50.0
# 6            4.166667   25.0
# 7            8.000000   48.0
# 8            5.166667   31.0
# 9            4.166667   25.0
