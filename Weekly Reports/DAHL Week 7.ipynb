# %% [markdown]
# # DAHL Week 6

# %% [markdown]
# ## Setup

# %%
import path
import os
from espn_api.hockey import League

# %%
setup_path = "C:/Users/jwini/OneDrive/Documents/Python Scripts/hockey-analytics/Setup Files/"
cred_fname = "credentials.py"
matchup_fname = "DAHL Matchup Stats.py"
player_fname = "DAHL Player Stats.py"

setup_files = [cred_fname, matchup_fname]

# %%
for f in setup_files:
    exec(open(os.path.join(setup_path, f)).read())

# %%
league = League(league_id = 1140371907, year = 2022, espn_s2 = espn_s2, swid = swid)

# %%
matchup_week1 = get_matchup_stats_to_df(1)
matchup_week2 = get_matchup_stats_to_df(2)
matchup_week3 = get_matchup_stats_to_df(3)
matchup_week4 = get_matchup_stats_to_df(4)
matchup_week5 = get_matchup_stats_to_df(5)
matchup_week6 = get_matchup_stats_to_df(6)
matchup_week7 = get_matchup_stats_to_df(7)

# %%
week1 = clean_matchup_df(matchup_week1)
week2 = clean_matchup_df(matchup_week2)
week3 = clean_matchup_df(matchup_week3)        
week4 = clean_matchup_df(matchup_week4)        
week5 = clean_matchup_df(matchup_week5)
week6 = clean_matchup_df(matchup_week6)
week7 = clean_matchup_df(matchup_week7)
matchup_weeks = [week1, week2, week3, week4, week5, week6, week7]

# %%
matchup_df_clean = clean_matchup_dfs(matchup_weeks)

# %% [markdown]
# ## Matchup Plots Week 6

# %%
plot_weekly_points(matchup_df_clean,8)

# %%
plot_week_bar(matchup_df_clean,7)

# %% [markdown]
# ### Fantasy Points (home points adjusted)

# %%
matchup_tables(matchup_df_clean, "Fantasy Points", False)
# Out:
# Week Number                     Team Name       1       2       3       4  \
# 2                           Carolina Tony  125.00  157.60  199.75  255.85
# 0                       Baltimore Bandits  158.80  202.95  223.55  192.15
# 6                           Team Ginsberg  137.40  166.05  173.35  251.10
# 3                   Esther Island Esthers  160.00  204.65  207.40  214.50
# 9                      Vasili's POD SQUAD  133.55  212.40  168.45  202.35
# 8                   That Hoser Over There  129.45  176.85  198.25  206.65
# 4                   Lausanne  Automatons   121.05  211.30  230.00  152.85
# 1            Brown Shoes w/ a Black Belt?  129.40  165.50  181.10  187.20
# 5                           THE FirePucks   88.60  191.50  147.50  169.35
# 7                             Team Hector  141.55  171.05   77.70  158.45
#
# Week Number       5       6       7     Average    Total
# 2            258.10  189.70  242.30  204.042857  1428.30
# 0            239.65  183.45  223.50  203.435714  1424.05
# 6            203.10  228.15  211.80  195.850000  1370.95
# 3            183.10  162.60  193.55  189.400000  1325.80
# 9            199.80  191.80  166.35  182.100000  1274.70
# 8            189.30  183.85  144.10  175.492857  1228.45
# 4            163.10  135.55  148.35  166.028571  1162.20
# 1            158.95  150.40  145.40  159.707143  1117.95
# 5            162.35  133.45  175.65  152.628571  1068.40
# 7            111.70  123.35  133.05  130.978571   916.85

# %% [markdown]
# ### Fantasy Points Against

# %%
matchup_tables(matchup_df_clean, "Opponent Fantasy Points", False)
# Out:
# Week Number                     Team Name       1       2       3       4  \
# 9                      Vasili's POD SQUAD  121.05  191.50  199.75  187.20
# 0                       Baltimore Bandits  129.40  176.85  230.00  169.35
# 8                   That Hoser Over There  160.00  202.95   77.70  251.10
# 1            Brown Shoes w/ a Black Belt?  158.80  211.30  147.50  202.35
# 3                   Esther Island Esthers  129.45  171.05  173.35  255.85
# 7                             Team Hector  125.00  204.65  198.25  152.85
# 5                           THE FirePucks  137.40  212.40  181.10  192.15
# 4                   Lausanne  Automatons   133.55  165.50  223.55  158.45
# 2                           Carolina Tony  141.55  166.05  168.45  214.50
# 6                           Team Ginsberg   88.60  157.60  207.40  206.65
#
# Week Number       5       6       7     Average    Total
# 9            239.65  183.85  211.80  190.685714  1334.80
# 0            199.80  228.15  193.55  189.585714  1327.10
# 8            258.10  191.80  148.35  184.285714  1290.00
# 1            183.10  123.35  242.30  181.242857  1268.70
# 3            158.95  133.45  223.50  177.942857  1245.60
# 7            203.10  150.40  175.65  172.842857  1209.90
# 5            163.10  162.60  133.05  168.828571  1181.80
# 4            162.35  189.70  144.10  168.171429  1177.20
# 2            189.30  135.55  145.40  165.828571  1160.80
# 6            111.70  183.45  166.35  160.250000  1121.75

# %% [markdown]
# # Fantasy Points Rank

# %% [markdown]
# Scale from 1-10. 1 means you had the most points that week, 10 means you had the least amount.

# %%
matchup_tables(matchup_df_clean, "Fantasy Points Rank", True)
# Out:
# Week Number                     Team Name     1     2     3     4     5     6  \
# 0                       Baltimore Bandits   2.0   4.0   2.0   6.0   2.0   5.0
# 3                   Esther Island Esthers   1.0   3.0   3.0   3.0   6.0   6.0
# 2                           Carolina Tony   8.0  10.0   4.0   1.0   1.0   3.0
# 6                           Team Ginsberg   4.0   8.0   7.0   2.0   3.0   1.0
# 9                      Vasili's POD SQUAD   5.0   1.0   8.0   5.0   4.0   2.0
# 8                   That Hoser Over There   6.0   6.0   5.0   4.0   5.0   4.0
# 4                   Lausanne  Automatons    9.0   2.0   1.0  10.0   7.0   8.0
# 1            Brown Shoes w/ a Black Belt?   7.0   9.0   6.0   7.0   9.0   7.0
# 5                           THE FirePucks  10.0   5.0   9.0   8.0   8.0   9.0
# 7                             Team Hector   3.0   7.0  10.0   9.0  10.0  10.0
#
# Week Number     7   Average  Total
# 0             2.0  3.285714   23.0
# 3             4.0  3.714286   26.0
# 2             1.0  4.000000   28.0
# 6             3.0  4.000000   28.0
# 9             6.0  4.428571   31.0
# 8             9.0  5.571429   39.0
# 4             7.0  6.285714   44.0
# 1             8.0  7.571429   53.0
# 5             5.0  7.714286   54.0
# 7            10.0  8.428571   59.0
